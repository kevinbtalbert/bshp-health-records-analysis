# %% [markdown]
# # Analysis with CSV Extracts

# %% [markdown]
# ## This analysis identifies all patients with Prediabetes as well as those within the past year

# %%
# Step 1: Import Necessary Libraries
import pandas as pd
from datetime import datetime

# Step 2: Load Data
conditions_path = "/home/cdsw/exported-data/hl7_condition.csv"
conditions_df = pd.read_csv(conditions_path, quotechar='"')

# Load the patient metadata
patient_pii_path = "/home/cdsw/exported-data/hl7_patient_pii.csv"
patient_metadata_df = pd.read_csv(patient_pii_path, quotechar='"')

# Step 3: Data Preprocessing
def preprocess_data(df):
    for col in df.columns:
        if df[col].dtype == object:
            df[col] = df[col].str.strip('"').str.strip('\'')
    return df

conditions_df = preprocess_data(conditions_df)

# %% [markdown]
# ### Identify all patients with prediabetes

# %%
# Convert 'onsetdatetime' from string to datetime and make it timezone aware
conditions_df['onsetdatetime'] = pd.to_datetime(conditions_df['onsetdatetime'], errors='coerce', utc=True)

# Filter for Prediabetes conditions only, removing the date restriction
conditions_df = conditions_df[
    (conditions_df['condition_display'] == "Prediabetes")
]

# Preprocess the patient metadata (ensure correct data types and stripping extra quotes)
patient_metadata_df = patient_metadata_df[['fullUrl', 'resource_name_0_family', 'resource_name_0_given_0']]

# Join the dataframes
prediabetes_patient_info_df = conditions_df.merge(
    patient_metadata_df,
    left_on='subject_reference',
    right_on='fullUrl',
    how='left'
)

# Make a copy to avoid SettingWithCopyWarning when renaming columns
final_df = prediabetes_patient_info_df[['condition_display', 'subject_reference', 'onsetdatetime', 'encounter_reference', 'resource_name_0_given_0', 'resource_name_0_family']].copy()
final_df.rename(columns={
    'resource_name_0_given_0': 'First Name',
    'resource_name_0_family': 'Last Name'
}, inplace=True)

# Display the final dataframe
print(final_df)
# Out:
#    condition_display                              subject_reference  \
# 0        Prediabetes  urn:uuid:2ee443fc-63eb-1706-3864-cc2646839e19
# 1        Prediabetes  urn:uuid:05c4608d-bd9a-5d04-41d7-a0293da7f5a5
# 2        Prediabetes  urn:uuid:35b7931d-e61b-9c71-7c78-26e97b6de524
# 3        Prediabetes  urn:uuid:1ffbf770-5e69-f93e-916c-a316002eead3
# 4        Prediabetes  urn:uuid:29257306-9929-b1f9-49f8-ac43800341fe
# 5        Prediabetes  urn:uuid:b6d3e48c-cb6a-5e32-167e-9dc2ebc0a007
# 6        Prediabetes  urn:uuid:0b595f34-417b-c1ca-6e47-5c9bc7d8f58e
# 7        Prediabetes  urn:uuid:090a02d7-c906-58e1-8697-046720cd40a7
# 8        Prediabetes  urn:uuid:eaa23cfe-4255-47fd-d741-b65bb704b8d2
# 9        Prediabetes  urn:uuid:54ac079a-90af-6fbd-bd78-34bcbc8308f3
# 10       Prediabetes  urn:uuid:e58f8f49-70af-e8fb-f52f-0d02b0b1fefd
# 11       Prediabetes  urn:uuid:dbbdea19-8376-10e8-c104-f23fe8fbf3fd
# 12       Prediabetes  urn:uuid:2b1f2ab3-4e87-85d1-304f-10250f4d8faf
# 13       Prediabetes  urn:uuid:9f492986-7b07-a295-41d7-25649666a479
# 14       Prediabetes  urn:uuid:d69759aa-a409-f8c0-1804-ead7023c66a2
# 15       Prediabetes  urn:uuid:8865b6f3-9074-2a99-ee6f-1595444dcb11
# 16       Prediabetes  urn:uuid:b8252f04-1084-2d8c-8f7e-34f6b9e8e8c4
# 17       Prediabetes  urn:uuid:fa5c2948-0731-7bb9-5b00-b6be2409cc99
# 18       Prediabetes  urn:uuid:50164fde-695f-07dc-9e8b-6c7107fe40c8
# 19       Prediabetes  urn:uuid:d3fd16ab-3b98-42ae-9c34-f838b7a34581
# 20       Prediabetes  urn:uuid:e1a90b76-c8fb-724a-5053-7355db36519b
# 21       Prediabetes  urn:uuid:1d267cc7-b806-e99b-aff9-080864aa6ede
# 22       Prediabetes  urn:uuid:e57a27a7-daee-cbd6-98e7-f893737d73a3
# 23       Prediabetes  urn:uuid:69ae0216-fd7e-dc14-da10-9eed5e80c3f8
# 24       Prediabetes  urn:uuid:ce91b7b5-7064-8e8e-6327-3d836b2e180a
# 25       Prediabetes  urn:uuid:8d198bbf-734c-e4f1-ac42-d844685d904f
# 26       Prediabetes  urn:uuid:901230b9-7bfd-dc9f-31c7-7e7c450942bd
# 27       Prediabetes  urn:uuid:0179b9e7-c04c-402d-c551-3e9cdb7c3a1c
# 28       Prediabetes  urn:uuid:afcdfeac-156e-9bc6-89cc-46e5556b32ad
# 29       Prediabetes  urn:uuid:849636e9-381e-c0a0-3811-2860baa4aa07
# 30       Prediabetes  urn:uuid:f2637b5d-5272-3657-d7b9-2137a9272298
# 31       Prediabetes  urn:uuid:ce87286f-07d8-2cf3-5267-79f5ba01780e
# 32       Prediabetes  urn:uuid:076a24c5-c7f3-c743-e882-34b41a8af35b
# 33       Prediabetes  urn:uuid:5bbae7c2-688b-4165-ae01-a29339cbd30d
# 34       Prediabetes  urn:uuid:4734cda8-5be9-a179-e553-c0339352af0f
# 35       Prediabetes  urn:uuid:370ed7f4-237b-654c-ae99-c929b8015adf
# 36       Prediabetes  urn:uuid:90a5fd34-004f-2d58-a92b-4ff48fa36036
# 37       Prediabetes  urn:uuid:6af5ef8e-3390-f40b-462c-3aeafa50abc5
# 38       Prediabetes  urn:uuid:2703570e-f634-d4cc-13db-2ae14e19ae59
# 39       Prediabetes  urn:uuid:8b7ada46-ea6a-bc88-99e0-f2d5376828fc
# 40       Prediabetes  urn:uuid:4c3c1493-31fb-654a-0ceb-bd9299e4f2d6
# 41       Prediabetes  urn:uuid:d9fa3557-a893-5fb2-c59c-bc6216447572
# 42       Prediabetes  urn:uuid:e30e7670-b324-3961-4fac-769fed001f35
# 43       Prediabetes  urn:uuid:86016de3-7412-912d-e8d0-cbe25646689d
# 44       Prediabetes  urn:uuid:240f8473-56ca-b227-99c8-5b7873300f9f
# 45       Prediabetes  urn:uuid:046da0d3-488d-ed35-cbb4-5fd2a4874707
# 46       Prediabetes  urn:uuid:dd735bf5-74eb-4ea6-f22d-c9744a1e7e6b
# 47       Prediabetes  urn:uuid:73eac583-9ff5-7e7e-933c-8d76959ad6e1
# 48       Prediabetes  urn:uuid:8bf8d9a1-af2a-1dfa-c39a-78f14c3dc387
# 49       Prediabetes  urn:uuid:88312c21-7986-0e8b-e811-30794c495d11
#
#                onsetdatetime                            encounter_reference  \
# 0  1980-08-23 18:50:19+00:00  urn:uuid:02d2dab2-5815-6d0a-43cf-023b8a2e267e
# 1  1943-09-08 06:56:35+00:00  urn:uuid:47b7a597-9249-7fa5-a7dc-92bfb2b1722c
# 2  2021-12-12 10:49:37+00:00  urn:uuid:0e636cdf-9876-454f-e5ea-f4e76ce32c3e
# 3  1947-09-17 06:56:35+00:00  urn:uuid:cf5a2486-3619-b1c8-651d-defff695ff14
# 4  2023-09-26 18:21:43+00:00  urn:uuid:56c54261-78c0-6552-77bf-820a14ffc0ec
# 5  1987-10-01 10:49:33+00:00  urn:uuid:27239f86-64f5-e9e6-06c5-532bafa19ba0
# 6  1981-02-18 12:58:20+00:00  urn:uuid:1b15249c-c2e5-4973-cb36-656a5a0ef5b4
# 7  2004-11-09 19:59:04+00:00  urn:uuid:f9d7ca76-c264-a907-08e8-ec6fe395ffa7
# 8  1988-10-28 01:10:32+00:00  urn:uuid:56fbf41c-885a-6ca0-4dfa-1caf9b26fe95
# 9  2019-04-26 08:38:10+00:00  urn:uuid:358cd8c9-7981-8ed7-8346-3a0036be1067
# 10 2020-05-13 11:21:09+00:00  urn:uuid:9128f6ac-b851-d810-fd2a-32384c30e231
# 11 2012-01-05 12:31:15+00:00  urn:uuid:dc217b11-5a5e-1cfc-27ed-5a4b9aa897bc
# 12 1971-06-01 18:40:12+00:00  urn:uuid:282daf63-2533-f8cb-1e3f-625807bfb9be
# 13 1940-09-04 06:56:35+00:00  urn:uuid:b1c0fb1e-280d-fea7-bde7-8a47724d7cd7
# 14 2021-03-01 02:08:55+00:00  urn:uuid:eb088ebc-c786-1cb2-f315-69246e283a21
# 15 1993-12-21 04:27:04+00:00  urn:uuid:49c83583-10b3-0fb9-3302-3bd95e8d2118
# 16 2005-07-21 17:44:11+00:00  urn:uuid:ea17df8e-41b9-9974-0a72-296c05419572
# 17 1986-12-27 21:00:53+00:00  urn:uuid:b55b2954-c9da-8ade-4d1b-50cb8d295b13
# 18 2005-10-04 11:00:10+00:00  urn:uuid:3255991c-7db5-9a6b-e799-917f3e476531
# 19 1988-07-03 02:02:56+00:00  urn:uuid:366241ab-2bf9-2ab3-e469-b4c5bbf19abf
# 20 2009-03-26 01:09:49+00:00  urn:uuid:dcea090c-e5fe-a482-446e-0f8b39a632b8
# 21 2016-05-17 18:15:49+00:00  urn:uuid:649e959d-0dc1-3f50-8f54-6535ce5ff1b0
# 22 2019-11-12 02:52:35+00:00  urn:uuid:931b3fac-868b-0b32-f191-a697581257e0
# 23 1985-02-23 17:03:09+00:00  urn:uuid:650809fb-ee88-6854-abb8-1952836d0acb
# 24 2023-11-14 08:50:58+00:00  urn:uuid:06d3dc30-0024-a472-990c-761ad33306d5
# 25 1955-05-08 18:46:42+00:00  urn:uuid:8a9b2959-b314-3597-4e6c-869705c2730f
# 26 1979-12-15 17:03:09+00:00  urn:uuid:718379c8-991b-430b-eec8-901788e4e163
# 27 2004-06-20 07:28:01+00:00  urn:uuid:087d5141-e4a2-342d-81ce-1cb3f0bf6685
# 28 2003-12-17 12:58:20+00:00  urn:uuid:5d37a5a8-d3cb-8e74-1072-0bb4cbda0afa
# 29 2012-12-13 06:22:04+00:00  urn:uuid:1b28c4bc-5a80-0823-7870-dce555ad12e0
# 30 1990-10-28 19:19:04+00:00  urn:uuid:8c2e45a2-0a69-b209-693d-d1fb74f15f23
# 31 2011-05-24 15:31:57+00:00  urn:uuid:76f7423c-2ae9-e94b-805a-352d2b2baf2e
# 32 1985-12-23 03:03:15+00:00  urn:uuid:1041f8c5-afc7-450d-0688-994fee54cb6d
# 33 1997-09-14 13:47:07+00:00  urn:uuid:9dbc95cd-3932-7077-fb32-c20c8f449661
# 34 2011-03-19 11:52:35+00:00  urn:uuid:54e7a5bc-102b-d5e5-4b29-35046948d38c
# 35 2001-02-07 03:46:54+00:00  urn:uuid:ac05ab2f-7668-fa56-bde2-919781d42127
# 36 1991-11-17 07:28:01+00:00  urn:uuid:edbf20f9-bb42-2ce4-3da7-8d6292ad54a2
# 37 2002-11-21 15:15:05+00:00  urn:uuid:ee3e1b0d-f6ee-bc64-02d7-8c95e6016beb
# 38 2024-03-23 00:34:37+00:00  urn:uuid:a7c99e0b-4c5b-1749-4d8d-870b2e885463
# 39 2007-03-10 09:12:01+00:00  urn:uuid:0b09343d-ffc0-118b-2c60-52f1647e07bf
# 40 2018-08-14 09:36:29+00:00  urn:uuid:13846d12-a952-dbad-a3c3-a560819ffa0f
# 41 1991-05-05 02:02:56+00:00  urn:uuid:3d916988-f42f-e1f3-bf62-7de55c074606
# 42 1989-07-22 23:59:57+00:00  urn:uuid:60e25e68-ddf4-b63a-9097-802277859929
# 43 2011-05-29 17:15:51+00:00  urn:uuid:acbb9249-6675-03c6-14f6-577e2d2f1911
# 44 1988-07-09 08:05:04+00:00  urn:uuid:a19fa733-6668-f214-6729-f0b97d518f62
# 45 1991-07-14 19:03:45+00:00  urn:uuid:3a5c57f6-0db1-3d3e-6b3b-3060ce2057b5
# 46 2021-01-18 05:22:14+00:00  urn:uuid:b92206fd-d158-6556-8bad-69eea5a96357
# 47 2015-10-25 19:19:04+00:00  urn:uuid:864b7b1c-b85f-8a84-4b60-6ebcec2e91b0
# 48 2018-12-29 08:18:40+00:00  urn:uuid:9c580532-7ce2-fd22-7cc7-7f1f979f99eb
# 49 1970-12-05 17:03:09+00:00  urn:uuid:7be8dd6f-1aa3-4c15-996b-57d5c0b29789
#
#        First Name       Last Name
# 0        Corey514      Gaylord332
# 1        Akiko835       Larkin917
# 2       Josiah310      Strosin214
# 3      Tabitha433  Stoltenberg489
# 4         Chet188        Bruen238
# 5      Elliott563    Wilderman619
# 6        Korey682       Abbott774
# 7          Sal878       Beahan375
# 8         Gita759       Daniel959
# 9        Dione665        O'Kon634
# 10     Francis500         Koss676
# 11       Ranee391       O'Keefe54
# 12      Nerissa37     Botsford977
# 13       Mamie949       Leannon79
# 14       Keira502        Hessel84
# 15     Cedrick207         King743
# 16       Damian46  Satterfield305
# 17     Joaquin141      Roberts511
# 18    Casandra937       Grimes165
# 19        Shira43         Mraz590
# 20      Annice210      McClure239
# 21   Margarite168     Turcotte120
# 22      Nikita578     Predovic534
# 23       Daron260       Hudson301
# 24       Carin553     Kassulke119
# 25        Meri607      Stracke611
# 26       Rocco842      Spencer878
# 27      Dennis979      Dickens475
# 28      Vernon254        Yundt842
# 29    Donnetta255        Ratke343
# 30      Hunter736         Moen819
# 31      Delmar187     Armstrong51
# 32      Arleen939        Kling921
# 33        Hollis7         Mraz590
# 34       Ronna740        Feeney44
# 35   Valentine262    Wilderman619
# 36    Emmanuel930      Effertz744
# 37     Shanika235    McDermott739
# 38       Norma469      Langosh790
# 39       Byron202       Rempel203
# 40        Leah288          Orn563
# 41  Jacqualine965    Aufderhar910
# 42      Nathan164          Rau926
# 43     Dominic463    Wilderman619
# 44      Luanne915         Veum823
# 45     Margart214     Bogisich202
# 46      Jesusa437        Mayer370
# 47         Jay242         Emard19
# 48    Christeen33      Schmitt836
# 49        Timmy68        Nolan344

# %% [markdown]
# ### Identify patients with prediabetes in the past year

# %%
# Convert 'onsetdatetime' from string to datetime and make it timezone aware
conditions_df['onsetdatetime'] = pd.to_datetime(conditions_df['onsetdatetime'], errors='coerce', utc=True)
current_date = pd.Timestamp.utcnow()
one_year_ago = current_date - pd.DateOffset(years=1)
conditions_df = conditions_df[
    (conditions_df['condition_display'] == "Prediabetes") &
    (conditions_df['onsetdatetime'] >= one_year_ago)
]

# # Preprocess the patient metadata (ensure correct data types and stripping extra quotes)
patient_metadata_df = patient_metadata_df[['fullUrl', 'resource_name_0_family', 'resource_name_0_given_0']]

# Join the dataframes
prediabetes_patient_info_df = conditions_df.merge(
    patient_metadata_df,
    left_on='subject_reference',
    right_on='fullUrl',
    how='left'
)

# Make a copy to avoid SettingWithCopyWarning when renaming columns
final_df = prediabetes_patient_info_df[['condition_display', 'subject_reference', 'onsetdatetime', 'encounter_reference', 'resource_name_0_given_0', 'resource_name_0_family']].copy()
final_df.rename(columns={
    'resource_name_0_given_0': 'First Name',
    'resource_name_0_family': 'Last Name'
}, inplace=True)

# Display the final dataframe
print(final_df)
# Out:
#   condition_display                              subject_reference  \
# 0       Prediabetes  urn:uuid:29257306-9929-b1f9-49f8-ac43800341fe
# 1       Prediabetes  urn:uuid:ce91b7b5-7064-8e8e-6327-3d836b2e180a
# 2       Prediabetes  urn:uuid:2703570e-f634-d4cc-13db-2ae14e19ae59
#
#               onsetdatetime                            encounter_reference  \
# 0 2023-09-26 18:21:43+00:00  urn:uuid:56c54261-78c0-6552-77bf-820a14ffc0ec
# 1 2023-11-14 08:50:58+00:00  urn:uuid:06d3dc30-0024-a472-990c-761ad33306d5
# 2 2024-03-23 00:34:37+00:00  urn:uuid:a7c99e0b-4c5b-1749-4d8d-870b2e885463
#
#   First Name    Last Name
# 0    Chet188     Bruen238
# 1   Carin553  Kassulke119
# 2   Norma469   Langosh790
